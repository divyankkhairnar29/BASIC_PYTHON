# %%
n=int(input())
for i in range(0,n):
  for j in range(0,n):
    print(i,j,end="  ")
  print()
# Out:
# 3
# 0 0  0 1  0 2
# 1 0  1 1  1 2
# 2 0  2 1  2 2

# %%
val=2
n=int(input())
for i in range(0,n+1):
  for j in range(0,n+1):
    print(i,end="  ")
  print()
# Out:
# 2
# 0  0  0
# 1  1  1
# 2  2  2

# %%
val=2
n=int(input())
for i in range(0,n+1):
  for j in range(0,n+1):
    print("*",end="  ")
  print()
# Out:
# 3
# *  *  *  *
# *  *  *  *
# *  *  *  *
# *  *  *  *

# %%
val=2
n=int(input())
for i in range(0,n):
  for j in range(0,n):
    print("*",end="  ")
  print()
# Out:
# 3
# *  *  *
# *  *  *
# *  *  *

# %%
val=2
n=int(input())
for i in range(0,n+1):
  for j in range(i+1):
    print("*",end="  ")
  print()
# Out:
# 3
# *
# *  *
# *  *  *
# *  *  *  *

# %%
val=2
n=int(input())
for i in range(0,n):
  for j in range(i+1):
    print("*",end="  ")
  print()
# Out:
# 3
# *
# *  *
# *  *  *

# %%
n=int(input())
for i in range(0,n):
  for j in range(0,n+1):
    print("*",end="  ")
if %2=0:
  print(i,end="  ")
else:
  print("*",end"  ")
print()
# Out:
# *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *
