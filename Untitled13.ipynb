# %%
a={1,2,4,6,3,2,6}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a|b
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a&b
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a-b
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.difference(b)
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.intersection(b)
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 7}

# %%
dct={1:"pqr"}
print(dct)
# Out:
# {1: 'pqr'}

# %%
for i in dct.keys():
  print(i)
# Out:
# 1

# %%
for i,j in dct.items():
  print(i,j)
# Out:
# 1 pqr

# %%
for i in dct.values():
  print(i)
# Out:
# pqr

# %%
dct={1:"abc",2:"pqr",3:"abc",4:"syz",5:"xyz"}
for keys,values in dct.items():
  print("Roll no=",keys,"name=",values)
# Out:
# Roll no= 1 name= abc
# Roll no= 2 name= pqr
# Roll no= 3 name= abc
# Roll no= 4 name= syz
# Roll no= 5 name= xyz

# %%
dct[6]="abc"
print(dct)
# Out:
# {1: 'abc', 2: 'pqr', 3: 'abc', 4: 'syz', 5: 'xyz', 6: 'abc'}

# %%
dct.get(2)
# Out:
# 'pqr'
