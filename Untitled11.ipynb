# %%
string=input("enter the string:")
n=len(string)
for i in range(n):
  for j in range(i):
    print("*",end="")
  print(string[i],end="")
  for j in range(n-i):
    print("*",end="")
  print()
# Out:
# enter the string:SANDIP
# S******
# *A*****
# **N****
# ***D***
# ****I**
# *****P*

# %%
s=input("enter the string:")
n=len(s)
for i in range(n):
  for j in range(n):
      if i==j or i+j==4:
          print(s[j],end="")
      else:
          print("*",end="")
  print()
# Out:
# enter the string:NAYAN
# N***N
# *A*A*
# **Y**
# *A*A*
# N***N

# %%
string=input("enter the string:")
n=len(string)
for i in range(n):
  for j in range(i):
    print("*",end="")
  print(string[i],end="")
  for j in range(n-i):
    print("*",end="")
  print()
# Out:
# enter the string:SANDIP
# S******
# *A*****
# **N****
# ***D***
# ****I**
# *****P*
