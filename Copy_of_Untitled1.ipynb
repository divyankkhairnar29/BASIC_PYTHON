# %%
print((2+3)/(4*3))
# Out:
# 0.4166666666666667

# %%
print(2+3/4*3)
# Out:
# 4.25

# %%
a=10
b=20
if a>b:
  print("a is greater")
else:
  print("b is greater")
# Out:
# b is greater

# %%
a=int(input())
if a>0:
  print('a is positive')
else :
  print('Number is negative')
# Out:
# 0
# Number is negative

# %%
chr(69)
# Out:
# 'E'

# %%
ord('a')
# Out:
# 97

# %%
m=int(input())
if m>90:
  print('A+')
elif m>80 and m<=90:
  print('A')
elif m>70 and m<=80:
  print('B+')
elif m>60 and m<=70:
  print('B')
elif m>50 and m<=60:
  print('C+')
elif m>40 and m<=50:
  print('C')
elif m<40:
  print('fail')
# Out:
# 39
# fail
