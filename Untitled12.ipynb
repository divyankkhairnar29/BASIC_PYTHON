# %%
string=input("Enter your string:")
result=""
for char in string:
  if 'a' <= char <= 'z':
    result=chr(ord(char)-32)
    print(result,end="")
  elif char in ' ':
    print(' ',end="")
  else:
    result=chr(ord(char)+32)
    print(result,end="")
# Out:
# Enter your string:Sandip Polytechnic
# sANDIP pOLYTECHNIC
