# %%
agent_letter ="B"
code_number = "5"
security_level = "2"

badge_number = ord(agent_letter)+ord(code_number)+ord(security_level)
print("Badge number is",badge_number)
# Out:
# Badge number is 169
